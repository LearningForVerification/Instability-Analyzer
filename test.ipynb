# %%
import onnx
from onnx import numpy_helper

# %%
onnx_model   = onnx.load(r"C:\Users\andr3\Desktop\Instability-Analizer\experiments\model.onnx")
initializer  = onnx_model.graph.initializer
onnx_weights = {i.name: numpy_helper.to_array(i) for i in initializer}

print(onnx_weights)
# Out:
# {'Linear_1_bias': array([-0.0206071 ,  0.08070582, -0.1290546 ,  0.16691497,  0.03747609,
#         0.04606529,  0.15081711,  0.13825132,  0.12112613, -0.2982993 ,
#        -0.07368065,  0.11219817,  0.3772791 ,  0.13638225,  0.15597433,
#        -0.1605408 ,  0.07068371,  0.22511952,  0.0731792 ,  0.19292036,
#         0.31208378, -0.18002592,  0.2737345 , -0.15607426, -0.07642039,
#         0.05728304, -0.21720225, -0.26749572,  0.15927514,  0.01584792,
#         0.11882019,  0.09510414,  0.11646093, -0.0660758 ,  0.08713678],
#       dtype=float32), 'Linear_1_weight': array([[ 5.3036005e-05,  3.9248960e-04, -6.1157433e-04, ...,
#         -7.6767727e-04,  5.3597975e-04, -1.2648460e-03],
#        [-3.4961605e-04, -1.0047422e-03, -7.4566115e-04, ...,
#         -5.1195984e-05, -2.3008157e-04, -4.6149374e-04],
#        [ 7.6076225e-04, -4.8006656e-05, -3.7416408e-04, ...,
#         -1.3575605e-03,  1.3267160e-04, -1.0047358e-03],
#        ...,
# ...
